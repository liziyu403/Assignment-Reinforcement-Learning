# %% [markdown]
# # Linear Value Function Approximation
# <center><img width="350"  align="right" src=attachment:DSME_logo.png /></center>
#
# **Reinforcement Learning and Learning-based Control** <br>
# RWTH Aachen University, DSME (Prof. Sebastian Trimpe) <br>
# *Code adapted from: https://github.com/ShangtongZhang/reinforcement-learning-an-introduction*

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ## Random Walk Example
# <center><img width="800" src=attachment:random_walk.png /></center>
#
# **Example 9.1 in Sutton & Barto:**
# Consider a
# 1000-state version of the random walk task (Examples 6.2 and 7.1 on pages 125 and
# 144). The states are numbered from 1 to 1000, left to right, and all episodes begin near
# the center, in state 500. State transitions are from the current state to one of the 100
# neighboring states to its left, or to one of the 100 neighboring states to its right, all with
# equal probability. Of course, if the current state is near an edge, then there may be fewer
# than 100 neighbors on that side of it. In this case, all the probability that would have
# gone into those missing neighbors goes into the probability of terminating on that side
# (thus, state 1 has a 0.5 chance of terminating on the left, and state 950 has a 0.25 chance
# of terminating on the right). As usual, termination on the left produces a reward of -1
# , and termination on the right produces a reward of +1. All other transitions have a
# reward of zero. We use this task as a running example throughout this section

# %% [markdown]
# Environment Hyperparameters

# %%
# set rewards and temporal discounting
REWARD_LEFT = -1
REWARD_RIGHT = 1
REWARD_BETWEEN = 0

GAMMA = 1

# # of states except for terminal states
N_STATES = 1000
# all states
STATES = np.arange(1, N_STATES + 1)
# start from a central state
START_STATE = 500
# terminal states
END_STATES = [0, N_STATES + 1]

# possible actions
ACTION_LEFT = -1
ACTION_RIGHT = 1
ACTIONS = [ACTION_LEFT, ACTION_RIGHT]
# maximum stride for an action
STEP_RANGE = 100

# %% [markdown]
# ## Tabular Dynamic Programming to compute 'true' Value Function

# %%
def compute_true_value():

    true_value = np.zeros((N_STATES + 2))

    # Dynamic programming to find the true state values
    while True:
        old_value = np.copy(true_value)
        for state in STATES:
            true_value[state] = 0
            for action in ACTIONS:
                for step in range(1, STEP_RANGE + 1):
                    step *= action
                    next_state = state + step
                    next_state = max(min(next_state, N_STATES + 1), 0)
                    # asynchronous update for faster convergence
                    if next_state == 0:
                        true_value[state] += 1.0 / (2 * STEP_RANGE) * (REWARD_LEFT + GAMMA * true_value[next_state])
                    elif next_state == N_STATES + 1:
                        true_value[state] += 1.0 / (2 * STEP_RANGE) * (REWARD_RIGHT + GAMMA * true_value[next_state])
                    else:
                        true_value[state] += 1.0 / (2 * STEP_RANGE) * (REWARD_BETWEEN + GAMMA * true_value[next_state])

        error = np.sum(np.abs(old_value - true_value))
        print('The remaining error is: ' + str(np.round(error, 3)))
        if error < 1e-2:
            break
    # correct the state value for terminal states to 0
    true_value[0] = true_value[-1] = 0

    return true_value

# %% [markdown]
# ## Random Walk Environment

# %%
# take an @action at @state, return new state and reward for this transition
def step(state, action):
    step = np.random.randint(1, STEP_RANGE + 1)
    step *= action
    state += step
    state = max(min(state, N_STATES + 1), 0)
    if state == 0:
        reward = REWARD_LEFT
    elif state == N_STATES + 1:
        reward = REWARD_RIGHT
    else:
        reward = REWARD_BETWEEN
    return state, reward

# %% [markdown]
# ## Random Policy

# %%
# get an action, following random policy
def get_action():
    if np.random.binomial(1, 0.5) == 1:
        return 1
    return -1

# %% [markdown]
# ## Different Types of Value Functions

# %%
# a wrapper class for aggregation value function
class ValueFunction:
    # @num_of_groups: # of aggregations
    def __init__(self, num_of_groups):
        self.num_of_groups = num_of_groups
        self.group_size = N_STATES // num_of_groups

        # thetas
        self.params = np.zeros(num_of_groups)

    # get the value of @state
    def value(self, state):
        if state in END_STATES:
            return 0
        group_index = (state - 1) // self.group_size
        return self.params[group_index]

    # update parameters
    # @delta: step size * (target - old estimation)
    # @state: state of current sample
    def update(self, delta, state):
        group_index = (state - 1) // self.group_size
        self.params[group_index] += delta

# a wrapper class for tile coding value function
class TilingsValueFunction:
    # @num_of_tilings: # of tilings
    # @tileWidth: each tiling has several tiles, this parameter specifies the width of each tile
    # @tilingOffset: specifies how tilings are put together
    def __init__(self, numOfTilings, tileWidth, tilingOffset):
        self.numOfTilings = numOfTilings
        self.tileWidth = tileWidth
        self.tilingOffset = tilingOffset

        # To make sure that each sate is covered by same number of tiles,
        # we need one more tile for each tiling
        self.tilingSize = N_STATES // tileWidth + 1

        # weight for each tile
        self.params = np.zeros((self.numOfTilings, self.tilingSize))

        # For performance, only track the starting position for each tiling
        # As we have one more tile for each tiling, the starting position will be negative
        self.tilings = np.arange(-tileWidth + 1, 0, tilingOffset)

    # get the value of @state
    def value(self, state):
        stateValue = 0.0
        # go through all the tilings
        for tilingIndex in range(0, len(self.tilings)):
            # find the active tile in current tiling
            tileIndex = (state - self.tilings[tilingIndex]) // self.tileWidth
            stateValue += self.params[tilingIndex, tileIndex]
        return stateValue

    # update parameters
    # @delta: step size * (target - old estimation)
    # @state: state of current sample
    def update(self, delta, state):

        # each state is covered by same number of tilings
        # so the delta should be divided equally into each tiling (tile)
        delta /= self.numOfTilings

        # go through all the tilings
        for tilingIndex in range(0, len(self.tilings)):
            # find the active tile in current tiling
            tileIndex = (state - self.tilings[tilingIndex]) // self.tileWidth
            self.params[tilingIndex, tileIndex] += delta

# a wrapper class for polynomial / Fourier -based value function
POLYNOMIAL_BASES = 0
FOURIER_BASES = 1
class BasesValueFunction:
    # @order: # of bases, each function also has one more constant parameter (called bias in machine learning)
    # @type: polynomial bases or Fourier bases
    def __init__(self, order, type):
        self.order = order
        self.weights = np.zeros(order + 1)

        # set up bases function
        self.bases = []
        if type == POLYNOMIAL_BASES:
            for i in range(0, order + 1):
                self.bases.append(lambda s, i=i: pow(s, i))
        elif type == FOURIER_BASES:
            for i in range(0, order + 1):
                self.bases.append(lambda s, i=i: np.cos(i * np.pi * s))

    # get the value of @state
    def value(self, state):
        # map the state space into [0, 1]
        state /= float(N_STATES)
        # get the feature vector
        feature = np.asarray([func(state) for func in self.bases])
        return np.dot(self.weights, feature)

    def update(self, delta, state):
        # map the state space into [0, 1]
        state /= float(N_STATES)
        # get derivative value
        derivative_value = np.asarray([func(state) for func in self.bases])
        self.weights += delta * derivative_value

class PolynomialValueFunction:
    def __init__(self, order):
        self.order = order
        self.weights = np.zeros(order +1)

    def featurize(self, state):
        feature = np.zeros(self.order + 1)
        state /= float(N_STATES)
        for i in range(self.order +1):
            feature[i] = state ** i
        return feature

    def value(self, state):
        return np.dot(self.featurize(state), self.weights)

    def update(self, delta, state):
        grad_v = self.featurize(state)
        self.weights += delta * grad_v

# %% [markdown]
# ## Gradient Monte-Carlo Algorithm
# (Sutton & Barto page 202)

# %%
def gradient_monte_carlo(value_function, alpha, distribution=None):
    state = START_STATE
    trajectory = np.array([[state, 0. ]])

    # We assume gamma = 1, so return is just the same as the latest reward
    #reward = 0.0
    while state not in END_STATES:
        action = get_action()
        next_state, reward = step(state, action)
        trajectory = np.append(trajectory, np.array([[next_state, reward]]), axis=0)
        state = next_state

    # Gradient update for each state in this trajectory

    ret = 0.0
    traj_len = trajectory.shape[0]
    for i in range(traj_len-1):
        state = int(trajectory[traj_len - 2 - i, 0])
        reward = int(trajectory[traj_len -1 - i, 1])
        ret = reward + GAMMA*ret
        delta = alpha * (ret - value_function.value(state))
        value_function.update(delta, state)
        if distribution is not None:
            distribution[state] += 1

# %% [markdown]
# ## Semi-gradient TD(0) Algorithm
# (Sutton & Barto page 203)

# %%
def semi_gradient_td_0(value_function, alpha, distribution=None):
    state = START_STATE

    while not state in END_STATES:
        action = get_action()
        next_state, reward = step(state, action)

        delta = alpha*(reward + GAMMA * value_function.value(next_state) - value_function.value(state))
        value_function.update(delta, state)
        if distribution is not None:
            distribution[state] += 1
        state = next_state

# %% [markdown]
# ### Compute true state value function using tabular dynamic programming

# %%
true_value = compute_true_value()
# Out:
# The remaining error is: 80.479
# The remaining error is: 52.208
# The remaining error is: 40.549
# The remaining error is: 34.116
# The remaining error is: 29.693
# The remaining error is: 26.237
# The remaining error is: 23.341
# The remaining error is: 20.825
# The remaining error is: 18.605
# The remaining error is: 16.631
# The remaining error is: 14.872
# The remaining error is: 13.302
# The remaining error is: 11.901
# The remaining error is: 10.648
# The remaining error is: 9.527
# The remaining error is: 8.524
# The remaining error is: 7.625
# The remaining error is: 6.82
# The remaining error is: 6.099
# The remaining error is: 5.453
# The remaining error is: 4.876
# The remaining error is: 4.36
# The remaining error is: 3.899
# The remaining error is: 3.488
# The remaining error is: 3.122
# The remaining error is: 2.797
# The remaining error is: 2.508
# The remaining error is: 2.251
# The remaining error is: 2.024
# The remaining error is: 1.824
# The remaining error is: 1.647
# The remaining error is: 1.491
# The remaining error is: 1.354
# The remaining error is: 1.234
# The remaining error is: 1.13
# The remaining error is: 1.039
# The remaining error is: 0.96
# The remaining error is: 0.892
# The remaining error is: 0.834
# The remaining error is: 0.785
# The remaining error is: 0.743
# The remaining error is: 0.709
# The remaining error is: 0.68
# The remaining error is: 0.657
# The remaining error is: 0.639
# The remaining error is: 0.624
# The remaining error is: 0.61
# The remaining error is: 0.597
# The remaining error is: 0.583
# The remaining error is: 0.569
# The remaining error is: 0.556
# The remaining error is: 0.542
# The remaining error is: 0.529
# The remaining error is: 0.515
# The remaining error is: 0.502
# The remaining error is: 0.489
# The remaining error is: 0.476
# The remaining error is: 0.464
# The remaining error is: 0.451
# The remaining error is: 0.439
# The remaining error is: 0.427
# The remaining error is: 0.415
# The remaining error is: 0.404
# The remaining error is: 0.393
# The remaining error is: 0.382
# The remaining error is: 0.371
# The remaining error is: 0.361
# The remaining error is: 0.35
# The remaining error is: 0.341
# The remaining error is: 0.331
# The remaining error is: 0.321
# The remaining error is: 0.312
# The remaining error is: 0.303
# The remaining error is: 0.295
# The remaining error is: 0.286
# The remaining error is: 0.278
# The remaining error is: 0.27
# The remaining error is: 0.262
# The remaining error is: 0.255
# The remaining error is: 0.247
# The remaining error is: 0.24
# The remaining error is: 0.233
# The remaining error is: 0.226
# The remaining error is: 0.22
# The remaining error is: 0.213
# The remaining error is: 0.207
# The remaining error is: 0.201
# The remaining error is: 0.195
# The remaining error is: 0.19
# The remaining error is: 0.184
# The remaining error is: 0.179
# The remaining error is: 0.173
# The remaining error is: 0.168
# The remaining error is: 0.163
# The remaining error is: 0.159
# The remaining error is: 0.154
# The remaining error is: 0.15
# The remaining error is: 0.145
# The remaining error is: 0.141
# The remaining error is: 0.137
# The remaining error is: 0.133
# The remaining error is: 0.129
# The remaining error is: 0.125
# The remaining error is: 0.121
# The remaining error is: 0.118
# The remaining error is: 0.114
# The remaining error is: 0.111
# The remaining error is: 0.108
# The remaining error is: 0.105
# The remaining error is: 0.102
# The remaining error is: 0.099
# The remaining error is: 0.096
# The remaining error is: 0.093
# The remaining error is: 0.09
# The remaining error is: 0.088
# The remaining error is: 0.085
# The remaining error is: 0.083
# The remaining error is: 0.08
# The remaining error is: 0.078
# The remaining error is: 0.075
# The remaining error is: 0.073
# The remaining error is: 0.071
# The remaining error is: 0.069
# The remaining error is: 0.067
# The remaining error is: 0.065
# The remaining error is: 0.063
# The remaining error is: 0.061
# The remaining error is: 0.06
# The remaining error is: 0.058
# The remaining error is: 0.056
# The remaining error is: 0.054
# The remaining error is: 0.053
# The remaining error is: 0.051
# The remaining error is: 0.05
# The remaining error is: 0.048
# The remaining error is: 0.047
# The remaining error is: 0.046
# The remaining error is: 0.044
# The remaining error is: 0.043
# The remaining error is: 0.042
# The remaining error is: 0.04
# The remaining error is: 0.039
# The remaining error is: 0.038
# The remaining error is: 0.037
# The remaining error is: 0.036
# The remaining error is: 0.035
# The remaining error is: 0.034
# The remaining error is: 0.033
# The remaining error is: 0.032
# The remaining error is: 0.031
# The remaining error is: 0.03
# The remaining error is: 0.029
# The remaining error is: 0.028
# The remaining error is: 0.027
# The remaining error is: 0.027
# The remaining error is: 0.026
# The remaining error is: 0.025
# The remaining error is: 0.024
# The remaining error is: 0.024
# The remaining error is: 0.023
# The remaining error is: 0.022
# The remaining error is: 0.022
# The remaining error is: 0.021
# The remaining error is: 0.02
# The remaining error is: 0.02
# The remaining error is: 0.019
# The remaining error is: 0.019
# The remaining error is: 0.018
# The remaining error is: 0.018
# The remaining error is: 0.017
# The remaining error is: 0.017
# The remaining error is: 0.016
# The remaining error is: 0.016
# The remaining error is: 0.015
# The remaining error is: 0.015
# The remaining error is: 0.014
# The remaining error is: 0.014
# The remaining error is: 0.013
# The remaining error is: 0.013
# The remaining error is: 0.013
# The remaining error is: 0.012
# The remaining error is: 0.012
# The remaining error is: 0.012
# The remaining error is: 0.011
# The remaining error is: 0.011
# The remaining error is: 0.011
# The remaining error is: 0.01
# The remaining error is: 0.01

# %% [markdown]
# ### MC learning with state aggregation feature

# %%
episodes = int(1e5)
alpha = 5e-5

# we have 10 aggregations in this example, each has 100 states
value_function = ValueFunction(10)

distribution = np.zeros(N_STATES + 2)
for ep in tqdm(range(episodes)):
    gradient_monte_carlo(value_function, alpha, distribution)
    
distribution /= np.sum(distribution)
state_values = [value_function.value(i) for i in STATES]

plt.figure(figsize=(10, 20))

plt.subplot(2, 1, 1)
plt.plot(STATES, state_values, label='Approximate MC value')
plt.plot(STATES, true_value[1: -1], label='True value')
plt.xlabel('State')
plt.ylabel('Value')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(STATES, distribution[1: -1], label='State distribution')
plt.xlabel('State')
plt.ylabel('Distribution')
plt.legend()
plt.show()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [01:54<00:00, 872.49it/s]

# %% [markdown]
# ### TD Learning with state aggregation feature

# %%
episodes = int(1e5)
alpha = 5e-5

# we have 10 aggregations in this example, each has 100 states
value_function = ValueFunction(10)

distribution = np.zeros(N_STATES + 2)
for ep in tqdm(range(episodes)):
    semi_gradient_td_0(value_function, alpha, distribution)
    
distribution /= np.sum(distribution)
state_values = [value_function.value(i) for i in STATES]

plt.figure(figsize=(10, 20))

plt.subplot(2, 1, 1)
plt.plot(STATES, state_values, label='Approximate TD value')
plt.plot(STATES, true_value[1: -1], label='True value')
plt.xlabel('State')
plt.ylabel('Value')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(STATES, distribution[1: -1], label='State distribution')
plt.xlabel('State')
plt.ylabel('Distribution')
plt.legend()
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:58<00:00, 1703.35it/s]

# %% [markdown]
# ### MC learning with polynomial feature (affine function)

# %%
episodes = int(5e5)
alpha = 2e-5

# polynomial of order 1
value_function = BasesValueFunction(1, POLYNOMIAL_BASES)

distribution = np.zeros(N_STATES + 2)
for ep in tqdm(range(episodes)):
    gradient_monte_carlo(value_function, alpha, distribution)
    
distribution /= np.sum(distribution)
state_values = [value_function.value(i) for i in STATES]

plt.figure(figsize=(10, 10))

plt.plot(STATES, state_values, label='Approximate MC value')
plt.plot(STATES, true_value[1: -1], label='True value')
plt.xlabel('State')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500000/500000 [15:31<00:00, 537.01it/s]

# %% [markdown]
# ### TD learning with polynomial feature (affine function)

# %%
episodes = int(5e5)
alpha = 2e-5

# polynomial of order 1
value_function = BasesValueFunction(1, POLYNOMIAL_BASES)

distribution = np.zeros(N_STATES + 2)
for ep in tqdm(range(episodes)):
    semi_gradient_td_0(value_function, alpha, distribution)
    
distribution /= np.sum(distribution)
state_values = [value_function.value(i) for i in STATES]

plt.figure(figsize=(10, 10))

plt.plot(STATES, state_values, label='Approximate TD value')
plt.plot(STATES, true_value[1: -1], label='True value')
plt.xlabel('State')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500000/500000 [15:45<00:00, 528.64it/s]

# %%
GAMMA = 0.5
true_value = compute_true_value()
episodes = int(5e5)
alpha = 2e-5

# polynomial of order 1
value_function = BasesValueFunction(1, POLYNOMIAL_BASES)

distribution = np.zeros(N_STATES + 2)
for ep in tqdm(range(episodes)):
    semi_gradient_td_0(value_function, alpha, distribution)
    
distribution /= np.sum(distribution)
state_values = [value_function.value(i) for i in STATES]

plt.figure(figsize=(10, 10))

plt.plot(STATES, state_values, label='Approximate TD value')
plt.plot(STATES, true_value[1: -1], label='True value')
plt.xlabel('State')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# The remaining error is: 61.134
# The remaining error is: 13.349
# The remaining error is: 3.501
# The remaining error is: 1.028
# The remaining error is: 0.319
# The remaining error is: 0.102
# The remaining error is: 0.033
# The remaining error is: 0.011
# The remaining error is: 0.004
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500000/500000 [15:49<00:00, 526.46it/s]

# %%
episodes = int(1e6)
alpha = 1e-4

# polynomial of order 5
value_function = BasesValueFunction(5, POLYNOMIAL_BASES)

distribution = np.zeros(N_STATES + 2)
for ep in tqdm(range(episodes)):
    semi_gradient_td_0(value_function, alpha, distribution)
    
distribution /= np.sum(distribution)
state_values = [value_function.value(i) for i in STATES]

plt.figure(figsize=(10, 10))

plt.plot(STATES, state_values, label='Approximate TD value')
plt.plot(STATES, true_value[1: -1], label='True value')
plt.xlabel('State')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000000/1000000 [33:23<00:00, 499.00it/s]

# %% [markdown]
# ### Change Reward function

# %%
REWARD_LEFT = 100
REWARD_RIGHT = 100
REWARD_BETWEEN = -1
GAMMA = 1
true_value = compute_true_value()

episodes = int(1e6)
alpha = 2e-5

# polynomial of order 2
value_function = BasesValueFunction(2, POLYNOMIAL_BASES)

distribution = np.zeros(N_STATES + 2)
for ep in tqdm(range(episodes)):
    gradient_monte_carlo(value_function, alpha, distribution)
    
distribution /= np.sum(distribution)
state_values = [value_function.value(i) for i in STATES]

plt.figure(figsize=(10, 10))

plt.plot(STATES, state_values, label='Approximate MC value')
plt.plot(STATES, true_value[1: -1], label='True value')
plt.xlabel('State')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# The remaining error is: 8381.782
# The remaining error is: 5096.687
# The remaining error is: 3626.171
# The remaining error is: 2766.109
# The remaining error is: 2181.69
# The remaining error is: 1755.192
# The remaining error is: 1433.345
# The remaining error is: 1186.492
# The remaining error is: 996.992
# The remaining error is: 854.516
# The remaining error is: 754.808
# The remaining error is: 698.556
# The remaining error is: 653.197
# The remaining error is: 614.762
# The remaining error is: 581.894
# The remaining error is: 553.542
# The remaining error is: 528.87
# The remaining error is: 507.191
# The remaining error is: 487.94
# The remaining error is: 470.649
# The remaining error is: 454.936
# The remaining error is: 440.491
# The remaining error is: 427.066
# The remaining error is: 414.466
# The remaining error is: 402.538
# The remaining error is: 391.165
# The remaining error is: 380.255
# The remaining error is: 369.742
# The remaining error is: 359.573
# The remaining error is: 349.709
# The remaining error is: 340.122
# The remaining error is: 330.79
# The remaining error is: 321.697
# The remaining error is: 312.832
# The remaining error is: 304.185
# The remaining error is: 295.75
# The remaining error is: 287.52
# The remaining error is: 279.492
# The remaining error is: 271.662
# The remaining error is: 264.027
# The remaining error is: 256.583
# The remaining error is: 249.327
# The remaining error is: 242.256
# The remaining error is: 235.368
# The remaining error is: 228.66
# The remaining error is: 222.127
# The remaining error is: 215.768
# The remaining error is: 209.579
# The remaining error is: 203.556
# The remaining error is: 197.697
# The remaining error is: 191.998
# The remaining error is: 186.455
# The remaining error is: 181.065
# The remaining error is: 175.825
# The remaining error is: 170.731
# The remaining error is: 165.779
# The remaining error is: 160.967
# The remaining error is: 156.29
# The remaining error is: 151.746
# The remaining error is: 147.331
# The remaining error is: 143.041
# The remaining error is: 138.874
# The remaining error is: 134.827
# The remaining error is: 130.895
# The remaining error is: 127.076
# The remaining error is: 123.367
# The remaining error is: 119.765
# The remaining error is: 116.267
# The remaining error is: 112.87
# The remaining error is: 109.572
# The remaining error is: 106.368
# The remaining error is: 103.258
# The remaining error is: 100.238
# The remaining error is: 97.306
# The remaining error is: 94.459
# The remaining error is: 91.695
# The remaining error is: 89.011
# The remaining error is: 86.406
# The remaining error is: 83.876
# The remaining error is: 81.421
# The remaining error is: 79.036
# The remaining error is: 76.722
# The remaining error is: 74.475
# The remaining error is: 72.294
# The remaining error is: 70.176
# The remaining error is: 68.12
# The remaining error is: 66.125
# The remaining error is: 64.187
# The remaining error is: 62.307
# The remaining error is: 60.481
# The remaining error is: 58.709
# The remaining error is: 56.989
# The remaining error is: 55.319
# The remaining error is: 53.698
# The remaining error is: 52.124
# The remaining error is: 50.596
# The remaining error is: 49.114
# The remaining error is: 47.674
# The remaining error is: 46.277
# The remaining error is: 44.921
# The remaining error is: 43.604
# The remaining error is: 42.326
# The remaining error is: 41.085
# The remaining error is: 39.881
# The remaining error is: 38.712
# The remaining error is: 37.577
# The remaining error is: 36.476
# The remaining error is: 35.407
# The remaining error is: 34.369
# The remaining error is: 33.361
# The remaining error is: 32.384
# The remaining error is: 31.434
# The remaining error is: 30.513
# The remaining error is: 29.618
# The remaining error is: 28.75
# The remaining error is: 27.907
# The remaining error is: 27.089
# The remaining error is: 26.295
# The remaining error is: 25.524
# The remaining error is: 24.776
# The remaining error is: 24.05
# The remaining error is: 23.345
# The remaining error is: 22.661
# The remaining error is: 21.996
# The remaining error is: 21.351
# The remaining error is: 20.726
# The remaining error is: 20.118
# The remaining error is: 19.528
# The remaining error is: 18.956
# The remaining error is: 18.4
# The remaining error is: 17.861
# The remaining error is: 17.337
# The remaining error is: 16.829
# The remaining error is: 16.336
# The remaining error is: 15.857
# The remaining error is: 15.392
# The remaining error is: 14.941
# The remaining error is: 14.503
# The remaining error is: 14.078
# The remaining error is: 13.665
# The remaining error is: 13.264
# The remaining error is: 12.875
# The remaining error is: 12.498
# The remaining error is: 12.132
# The remaining error is: 11.776
# The remaining error is: 11.431
# The remaining error is: 11.096
# The remaining error is: 10.77
# The remaining error is: 10.455
# The remaining error is: 10.148
# The remaining error is: 9.851
# The remaining error is: 9.562
# The remaining error is: 9.282
# The remaining error is: 9.01
# The remaining error is: 8.745
# The remaining error is: 8.489
# The remaining error is: 8.24
# The remaining error is: 7.999
# The remaining error is: 7.764
# The remaining error is: 7.537
# The remaining error is: 7.316
# The remaining error is: 7.101
# The remaining error is: 6.893
# The remaining error is: 6.691
# The remaining error is: 6.495
# The remaining error is: 6.304
# The remaining error is: 6.12
# The remaining error is: 5.94
# The remaining error is: 5.766
# The remaining error is: 5.597
# The remaining error is: 5.433
# The remaining error is: 5.274
# The remaining error is: 5.119
# The remaining error is: 4.969
# The remaining error is: 4.823
# The remaining error is: 4.682
# The remaining error is: 4.545
# The remaining error is: 4.411
# The remaining error is: 4.282
# The remaining error is: 4.157
# The remaining error is: 4.035
# The remaining error is: 3.916
# The remaining error is: 3.802
# The remaining error is: 3.69
# The remaining error is: 3.582
# The remaining error is: 3.477
# The remaining error is: 3.375
# The remaining error is: 3.276
# The remaining error is: 3.18
# The remaining error is: 3.087
# The remaining error is: 2.996
# The remaining error is: 2.909
# The remaining error is: 2.823
# The remaining error is: 2.741
# The remaining error is: 2.66
# The remaining error is: 2.582
# The remaining error is: 2.506
# The remaining error is: 2.433
# The remaining error is: 2.362
# The remaining error is: 2.292
# The remaining error is: 2.225
# The remaining error is: 2.16
# The remaining error is: 2.097
# The remaining error is: 2.035
# The remaining error is: 1.976
# The remaining error is: 1.918
# The remaining error is: 1.861
# The remaining error is: 1.807
# The remaining error is: 1.754
# The remaining error is: 1.702
# The remaining error is: 1.653
# The remaining error is: 1.604
# The remaining error is: 1.557
# The remaining error is: 1.511
# The remaining error is: 1.467
# The remaining error is: 1.424
# The remaining error is: 1.382
# The remaining error is: 1.342
# The remaining error is: 1.303
# The remaining error is: 1.264
# The remaining error is: 1.227
# The remaining error is: 1.191
# The remaining error is: 1.156
# The remaining error is: 1.122
# The remaining error is: 1.09
# The remaining error is: 1.058
# The remaining error is: 1.027
# The remaining error is: 0.997
# The remaining error is: 0.967
# The remaining error is: 0.939
# The remaining error is: 0.911
# The remaining error is: 0.885
# The remaining error is: 0.859
# The remaining error is: 0.834
# The remaining error is: 0.809
# The remaining error is: 0.785
# The remaining error is: 0.762
# The remaining error is: 0.74
# The remaining error is: 0.718
# The remaining error is: 0.697
# The remaining error is: 0.677
# The remaining error is: 0.657
# The remaining error is: 0.638
# The remaining error is: 0.619
# The remaining error is: 0.601
# The remaining error is: 0.583
# The remaining error is: 0.566
# The remaining error is: 0.55
# The remaining error is: 0.534
# The remaining error is: 0.518
# The remaining error is: 0.503
# The remaining error is: 0.488
# The remaining error is: 0.474
# The remaining error is: 0.46
# The remaining error is: 0.446
# The remaining error is: 0.433
# The remaining error is: 0.42
# The remaining error is: 0.408
# The remaining error is: 0.396
# The remaining error is: 0.385
# The remaining error is: 0.373
# The remaining error is: 0.362
# The remaining error is: 0.352
# The remaining error is: 0.341
# The remaining error is: 0.331
# The remaining error is: 0.322
# The remaining error is: 0.312
# The remaining error is: 0.303
# The remaining error is: 0.294
# The remaining error is: 0.286
# The remaining error is: 0.277
# The remaining error is: 0.269
# The remaining error is: 0.261
# The remaining error is: 0.254
# The remaining error is: 0.246
# The remaining error is: 0.239
# The remaining error is: 0.232
# The remaining error is: 0.225
# The remaining error is: 0.219
# The remaining error is: 0.212
# The remaining error is: 0.206
# The remaining error is: 0.2
# The remaining error is: 0.194
# The remaining error is: 0.188
# The remaining error is: 0.183
# The remaining error is: 0.177
# The remaining error is: 0.172
# The remaining error is: 0.167
# The remaining error is: 0.162
# The remaining error is: 0.158
# The remaining error is: 0.153
# The remaining error is: 0.148
# The remaining error is: 0.144
# The remaining error is: 0.14
# The remaining error is: 0.136
# The remaining error is: 0.132
# The remaining error is: 0.128
# The remaining error is: 0.124
# The remaining error is: 0.121
# The remaining error is: 0.117
# The remaining error is: 0.114
# The remaining error is: 0.11
# The remaining error is: 0.107
# The remaining error is: 0.104
# The remaining error is: 0.101
# The remaining error is: 0.098
# The remaining error is: 0.095
# The remaining error is: 0.092
# The remaining error is: 0.09
# The remaining error is: 0.087
# The remaining error is: 0.084
# The remaining error is: 0.082
# The remaining error is: 0.079
# The remaining error is: 0.077
# The remaining error is: 0.075
# The remaining error is: 0.073
# The remaining error is: 0.071
# The remaining error is: 0.068
# The remaining error is: 0.066
# The remaining error is: 0.065
# The remaining error is: 0.063
# The remaining error is: 0.061
# The remaining error is: 0.059
# The remaining error is: 0.057
# The remaining error is: 0.056
# The remaining error is: 0.054
# The remaining error is: 0.052
# The remaining error is: 0.051
# The remaining error is: 0.049
# The remaining error is: 0.048
# The remaining error is: 0.047
# The remaining error is: 0.045
# The remaining error is: 0.044
# The remaining error is: 0.043
# The remaining error is: 0.041
# The remaining error is: 0.04
# The remaining error is: 0.039
# The remaining error is: 0.038
# The remaining error is: 0.037
# The remaining error is: 0.036
# The remaining error is: 0.035
# The remaining error is: 0.034
# The remaining error is: 0.033
# The remaining error is: 0.032
# The remaining error is: 0.031
# The remaining error is: 0.03
# The remaining error is: 0.029
# The remaining error is: 0.028
# The remaining error is: 0.027
# The remaining error is: 0.026
# The remaining error is: 0.026
# The remaining error is: 0.025
# The remaining error is: 0.024
# The remaining error is: 0.023
# The remaining error is: 0.023
# The remaining error is: 0.022
# The remaining error is: 0.021
# The remaining error is: 0.021
# The remaining error is: 0.02
# The remaining error is: 0.02
# The remaining error is: 0.019
# The remaining error is: 0.018
# The remaining error is: 0.018
# The remaining error is: 0.017
# The remaining error is: 0.017
# The remaining error is: 0.016
# The remaining error is: 0.016
# The remaining error is: 0.015
# The remaining error is: 0.015
# The remaining error is: 0.015
# The remaining error is: 0.014
# The remaining error is: 0.014
# The remaining error is: 0.013
# The remaining error is: 0.013
# The remaining error is: 0.013
# The remaining error is: 0.012
# The remaining error is: 0.012
# The remaining error is: 0.011
# The remaining error is: 0.011
# The remaining error is: 0.011
# The remaining error is: 0.011
# The remaining error is: 0.01
# The remaining error is: 0.01
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000000/1000000 [29:44<00:00, 560.35it/s]
